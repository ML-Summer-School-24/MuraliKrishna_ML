# %%
# 1.Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score
from colorama import Fore,Style
from sklearn.ensemble import RandomForestClassifier

print(Fore.GREEN + Style.BRIGHT + 'THE REQUIRED LIBRARIES WERE SUCCESSFULLY IMPORTED')
# Out:
# THE REQUIRED LIBRARIES WERE SUCCESSFULLY IMPORTED

# %%
# 2.Loading the CSV file

filePath = r"C:\Users\Murali Krishna\Downloads\winequality-red.csv"
data = pd.read_csv(filePath)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# 3.Data Pre-Processing


# 3.1 Deleting the outliers
print("Before Removing the outliers", data.shape)
data = data[data['total sulfur dioxide']<160]
print("After Removing the outliers", data.shape)
print("-----------------------------------------------------------------")

X = data.drop('quality',axis=1)
Y = data['quality'].apply(lambda y_value: 1 if y_value >= 5 else 0)
print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
print("-----------------------------------------------------------------")

# 3.2 Handling Missing Values
null_counts = data.isnull().sum()
print(null_counts)
print(Fore.GREEN + Style.BRIGHT + "Totally, there are {null_counts.sum()} null values in the dataset.")
print("-----------------------------------------------------------------")

# 3.3 Handling Duplicates
duplicate_count = data.duplicated().sum()
if duplicate_count == 0:
    print(Fore.GREEN + Style.BRIGHT + "No duplicate entries found in the dataset.")
else:
    print(Fore.GREEN + Style.BRIGHT + "Number of duplicate entries found: {duplicate_count}")
# Out:
# Before Removing the outliers (1599, 12)
# After Removing the outliers (1595, 12)
# -----------------------------------------------------------------
# Shape of X: (1595, 11)
# Shape of Y: (1595,)
# -----------------------------------------------------------------
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# Totally, there are {null_counts.sum()} null values in the dataset.
# -----------------------------------------------------------------
# Number of duplicate entries found: {duplicate_count}

# %%
# 4.Basic Details of the Data-Set

print("The shape =",data.shape)

# 4.1 Show information about the dataset
num_rows, num_cols = data.shape
num_features = num_cols - 1
num_data = num_rows * num_cols
print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_cols}")
print(f"Number of Features: {num_features}")
print(f"Number of All Data: {num_data}")
print("-----------------------------------------------------------------")

# 4.2 Get basic information
print(data.info())
print("-----------------------------------------------------------------")

# 4.3 Descriptive Statistics of Numeric Variables
data.describe().T.round(2)
# Out:
# The shape = (1595, 12)
# Number of Rows: 1595
# Number of Columns: 12
# Number of Features: 11
# Number of All Data: 19140
# -----------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 1595 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1595 non-null   float64
#  1   volatile acidity      1595 non-null   float64
#  2   citric acid           1595 non-null   float64
#  3   residual sugar        1595 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1595 non-null   float64
#  6   total sulfur dioxide  1595 non-null   float64
#  7   density               1595 non-null   float64
#  8   pH                    1595 non-null   float64
#  9   sulphates             1595 non-null   float64
#  10  alcohol               1595 non-null   float64
# ...

# %%
# 5.Data Plotting

# 5.1 Bar Graph
sns.catplot(data=data, x='quality', kind='count')
plt.title('Distribution of Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()
print("--------------------------------------------------------------------------------------------------------------------------------------------")

# 5.2 Histograms
data.hist(figsize=(12, 8))
plt.tight_layout()
plt.show()
print("--------------------------------------------------------------------------------------------------------------------------------------------")

# 5.3 Pie Chart
data.quality.value_counts().plot.pie(autopct='%1.1f%%', shadow=True, figsize=(10, 10))
plt.title('Quality Graph')
plt.legend()
plt.show()
print("--------------------------------------------------------------------------------------------------------------------------------------------")

# 5.4 Correlation Matrix using Heatmap
correlation = data.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True)
plt.title("Correlation Matrix")
plt.show()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------
